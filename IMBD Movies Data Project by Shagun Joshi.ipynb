# %% [markdown]
# # IMBD Movies Data Analysis....

# %%
import numpy as np
import pandas as pd

# %%
movie = pd.read_csv("IMDB_Movie_Data.csv", index_col='Title')

# %%
movie.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movie.shape
# Out:
# (1000, 11)

# %%
movie.describe().transpose()
# Out:
#                      count           mean            std     min       25%  \
# Rank                1000.0     500.500000     288.819436     1.0    250.75
# Year                1000.0    2012.783000       3.205962  2006.0   2010.00
# Runtime (Minutes)   1000.0     113.172000      18.810908    66.0    100.00
# Rating              1000.0       6.723200       0.945429     1.9      6.20
# Votes               1000.0  169808.255000  188762.647518    61.0  36309.00
# Revenue (Millions)   872.0      82.956376     103.253540     0.0     13.27
# Metascore            936.0      58.985043      17.194757    11.0     47.00
#
#                            50%         75%         max
# Rank                   500.500     750.250     1000.00
# Year                  2014.000    2016.000     2016.00
# Runtime (Minutes)      111.000     123.000      191.00
# Rating                   6.800       7.400        9.00
# Votes               110799.000  239909.750  1791916.00
# ...

# %%
movie.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
perct_mis_val = round(100*(movie.isnull().sum()/len(movie.index)),2)
print(perct_mis_val)
# Out:
# Rank                   0.0
# Genre                  0.0
# Description            0.0
# Director               0.0
# Actors                 0.0
# Year                   0.0
# Runtime (Minutes)      0.0
# Rating                 0.0
# Votes                  0.0
# Revenue (Millions)    12.8
# Metascore              6.4
# dtype: float64

# %% [markdown]
# **1-Handle the missing value columns with the proper assumtion.**

# %%
movie['Revenue (Millions)'] = movie['Revenue (Millions)'].fillna(movie['Revenue (Millions)'].mean())
movie['Metascore'] = movie['Metascore'].fillna(movie['Metascore'].mean())

# %%
movie.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# **2-Rename the columns for the analysis purpose if any columns are not in proper way.**

# %%
movie.rename(columns={"Runtime (Minutes)":'Runtime','Revenue (Millions)':'Revenue'})
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# **3-Generate the relationship between each continuous variable using corr() method.**

# %%
movie.corr()
# Out:
#                         Rank      Year  Runtime (Minutes)    Rating     Votes  \
# Rank                1.000000 -0.261605          -0.221739 -0.219555 -0.283876
# Year               -0.261605  1.000000          -0.164900 -0.211219 -0.411904
# Runtime (Minutes)  -0.221739 -0.164900           1.000000  0.392214  0.407062
# Rating             -0.219555 -0.211219           0.392214  1.000000  0.511537
# Votes              -0.283876 -0.411904           0.407062  0.511537  1.000000
# Revenue (Millions) -0.252996 -0.117562           0.247834  0.189527  0.607941
# Metascore          -0.185159 -0.076077           0.202239  0.604723  0.318116
#
#                     Revenue (Millions)  Metascore
# Rank                         -0.252996  -0.185159
# Year                         -0.117562  -0.076077
# Runtime (Minutes)             0.247834   0.202239
# Rating                        0.189527   0.604723
# Votes                         0.607941   0.318116
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(movie.corr())

# %% [markdown]
# **4-Find the movies directed by 'James Gunn', & 'Ridley Scott' with the rating greater than or equal to 8.**

# %%
movie['Director']
# Out:
# Title
# Guardians of the Galaxy              James Gunn
# Prometheus                         Ridley Scott
# Split                        M. Night Shyamalan
# Sing                       Christophe Lourdelet
# Suicide Squad                        David Ayer
#                                    ...
# Secret in Their Eyes                  Billy Ray
# Hostel: Part II                        Eli Roth
# Step Up 2: The Streets               Jon M. Chu
# Search Party                     Scot Armstrong
# Nine Lives                     Barry Sonnenfeld
# Name: Director, Length: 1000, dtype: object

# %%
movie.loc[(movie['Director']=='James Gunn') & (movie['Rating']>=8)]
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0

# %%
movie.loc[(movie['Director']=='Ridley Scott') & (movie['Rating']>=8)]
# Out:
#              Rank                   Genre  \
# Title
# The Martian   103  Adventure,Drama,Sci-Fi
#
#                                                    Description      Director  \
# Title
# The Martian  An astronaut becomes stranded on Mars after hi...  Ridley Scott
#
#                                                         Actors  Year  \
# Title
# The Martian  Matt Damon, Jessica Chastain, Kristen Wiig, Ka...  2015
#
#              Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# Title
# The Martian                144     8.0  556097              228.43       80.0

# %% [markdown]
# **6-Display all the director's who got the rating >= 8 for their movies.**

# %%
movie.loc[(movie['Rating'] >= 8)]
# Out:
#                           Rank                       Genre  \
# Title
# Guardians of the Galaxy      1     Action,Adventure,Sci-Fi
# La La Land                   7          Comedy,Drama,Music
# Hacksaw Ridge               17     Biography,Drama,History
# Lion                        19             Biography,Drama
# Arrival                     20        Drama,Mystery,Sci-Fi
# ...                        ...                         ...
# El secreto de sus ojos     743       Drama,Mystery,Romance
# PK                         766        Comedy,Drama,Romance
# How to Train Your Dragon   773  Animation,Action,Adventure
# Koe no katachi             862     Animation,Drama,Romance
# Taare Zameen Par           992          Drama,Family,Music
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# La La Land                A jazz pianist falls for an aspiring actress i...
# ...

# %%
type(movie[movie['Rating'] >= 8.0])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **7-Find all the movies directed by 'James Gunn', & 'Ridley Scott'.**

# %%
movie.loc[(movie['Director']=='James Gunn')]
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
# Slither                   909     Comedy,Horror,Sci-Fi
# Super                     938             Comedy,Drama
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Slither                  A small town is taken over by an alien plague,...
# Super                    After his wife falls under the influence of a ...
#
#                            Director  \
# Title
# Guardians of the Galaxy  James Gunn
# Slither                  James Gunn
# Super                    James Gunn
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Slither                  Nathan Fillion, Elizabeth Banks, Michael Rooke...
# ...

# %%
movie.loc[(movie['Director']=='Ridley Scott')]
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# The Martian             An astronaut becomes stranded on Mars after hi...
# Robin Hood              In 12th century England, Robin and his band of...
# American Gangster       In 1970s America, a detective works to bring d...
# Exodus: Gods and Kings  The defiant leader Moses rises up against the ...
# ...

# %%
movie.loc[(movie['Director']=='James Gunn') | (movie['Director']=='Ridley Scott')]
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# The Martian               103    Adventure,Drama,Sci-Fi
# Robin Hood                388    Action,Adventure,Drama
# American Gangster         471     Biography,Crime,Drama
# Exodus: Gods and Kings    517    Action,Adventure,Drama
# The Counselor             522      Crime,Drama,Thriller
# A Good Year               531      Comedy,Drama,Romance
# Body of Lies              738      Action,Drama,Romance
# Slither                   909      Comedy,Horror,Sci-Fi
# Super                     938              Comedy,Drama
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %% [markdown]
# **8-Display all the movies with the ratings between 8 & 9 and also the films with the highest rating.**

# %%
movie.loc[(movie['Rating']>=8) & (movie['Rating']<=9)]
# Out:
#                           Rank                       Genre  \
# Title
# Guardians of the Galaxy      1     Action,Adventure,Sci-Fi
# La La Land                   7          Comedy,Drama,Music
# Hacksaw Ridge               17     Biography,Drama,History
# Lion                        19             Biography,Drama
# Arrival                     20        Drama,Mystery,Sci-Fi
# ...                        ...                         ...
# El secreto de sus ojos     743       Drama,Mystery,Romance
# PK                         766        Comedy,Drama,Romance
# How to Train Your Dragon   773  Animation,Action,Adventure
# Koe no katachi             862     Animation,Drama,Romance
# Taare Zameen Par           992          Drama,Family,Music
#
#                                                                 Description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# La La Land                A jazz pianist falls for an aspiring actress i...
# ...

# %%
highest_rat = movie['Rating'].max()
highest_rat
# Out:
# 9.0

# %%
movie.loc[(movie["Rating"]==highest_rat)]
# Out:
#                  Rank               Genre  \
# Title
# The Dark Knight    55  Action,Crime,Drama
#
#                                                        Description  \
# Title
# The Dark Knight  When the menace known as the Joker wreaks havo...
#
#                           Director  \
# Title
# The Dark Knight  Christopher Nolan
#
#                                                             Actors  Year  \
# Title
# The Dark Knight  Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
#
#                  Runtime (Minutes)  Rating    Votes  Revenue (Millions)  \
# Title
# The Dark Knight                152     9.0  1791916              533.32
#
#                  Metascore
# Title
# The Dark Knight       82.0

# %% [markdown]
# **9-Find the movies directed by both 'Christopher Nolan' and 'Ridley Scott'**

# %%
movie.loc[(movie['Director']=='Christopher Nolan') | (movie['Director']=='Ridley Scott')]
# Out:
#                         Rank                     Genre  \
# Title
# Prometheus                 2  Adventure,Mystery,Sci-Fi
# Interstellar              37    Adventure,Drama,Sci-Fi
# The Dark Knight           55        Action,Crime,Drama
# The Prestige              65      Drama,Mystery,Sci-Fi
# Inception                 81   Action,Adventure,Sci-Fi
# The Martian              103    Adventure,Drama,Sci-Fi
# The Dark Knight Rises    125           Action,Thriller
# Robin Hood               388    Action,Adventure,Drama
# American Gangster        471     Biography,Crime,Drama
# Exodus: Gods and Kings   517    Action,Adventure,Drama
# The Counselor            522      Crime,Drama,Thriller
# A Good Year              531      Comedy,Drama,Romance
# Body of Lies             738      Action,Drama,Romance
#
#                                                               Description  \
# Title
# Prometheus              Following clues to the origin of mankind, a te...
# ...

# %%
movie[movie['Director'].isin(['Christopher Nolan', 'Ridley Scott'])].head()
# Out:
#                  Rank                     Genre  \
# Title
# Prometheus          2  Adventure,Mystery,Sci-Fi
# Interstellar       37    Adventure,Drama,Sci-Fi
# The Dark Knight    55        Action,Crime,Drama
# The Prestige       65      Drama,Mystery,Sci-Fi
# Inception          81   Action,Adventure,Sci-Fi
#
#                                                        Description  \
# Title
# Prometheus       Following clues to the origin of mankind, a te...
# Interstellar     A team of explorers travel through a wormhole ...
# The Dark Knight  When the menace known as the Joker wreaks havo...
# The Prestige     Two stage magicians engage in competitive one-...
# Inception        A thief, who steals corporate secrets through ...
#
#                           Director  \
# Title
# Prometheus            Ridley Scott
# Interstellar     Christopher Nolan
# The Dark Knight  Christopher Nolan
# The Prestige     Christopher Nolan
# Inception        Christopher Nolan
#
# ...

# %% [markdown]
# **10-Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 50th percentile in revenue.**

# %%
movie.loc[(movie['Year']>=2006) & (movie["Year"]<=2010) & (movie['Rating']>8)].head()
# Out:
#                       Rank                    Genre  \
# Title
# The Dark Knight         55       Action,Crime,Drama
# The Prestige            65     Drama,Mystery,Sci-Fi
# Inglourious Basterds    78      Adventure,Drama,War
# Inception               81  Action,Adventure,Sci-Fi
# The Departed           100     Crime,Drama,Thriller
#
#                                                             Description  \
# Title
# The Dark Knight       When the menace known as the Joker wreaks havo...
# The Prestige          Two stage magicians engage in competitive one-...
# Inglourious Basterds  In Nazi-occupied France during World War II, a...
# Inception             A thief, who steals corporate secrets through ...
# The Departed          An undercover cop and a mole in the police att...
#
#                                Director  \
# Title
# The Dark Knight       Christopher Nolan
# The Prestige          Christopher Nolan
# Inglourious Basterds  Quentin Tarantino
# ...

# %%
movie[(movie['Year']>=2006) & (movie["Year"]<=2010) & (movie['Rating']>8) & 
      (movie['Revenue (Millions)'] < movie['Revenue (Millions)'].quantile(0.50))][:5]
# Out:
#                      Rank                      Genre  \
# Title
# The Prestige           65       Drama,Mystery,Sci-Fi
# Into the Wild         198  Adventure,Biography,Drama
# Pan's Labyrinth       231          Drama,Fantasy,War
# There Will Be Blood   300              Drama,History
# 3 Idiots              431               Comedy,Drama
#
#                                                            Description  \
# Title
# The Prestige         Two stage magicians engage in competitive one-...
# Into the Wild        After graduating from Emory University, top st...
# Pan's Labyrinth      In the falangist Spain of 1944, the bookish yo...
# There Will Be Blood  A story of family, religion, hatred, oil and m...
# 3 Idiots             Two friends are searching for their long lost ...
#
#                                  Director  \
# Title
# The Prestige            Christopher Nolan
# Into the Wild                   Sean Penn
# Pan's Labyrinth        Guillermo del Toro
# ...

# %%
condition_1 = ((movie['Year'] >= 2006) & (movie['Year'] <= 2010))
condition_2 = (movie['Rating'] > 8.0) & (movie['Revenue (Millions)'] < movie['Revenue (Millions)'].quantile(0.5))
movie[condition_1 & condition_2]
# Out:
#                         Rank                      Genre  \
# Title
# The Prestige              65       Drama,Mystery,Sci-Fi
# Into the Wild            198  Adventure,Biography,Drama
# Pan's Labyrinth          231          Drama,Fantasy,War
# There Will Be Blood      300              Drama,History
# 3 Idiots                 431               Comedy,Drama
# The Lives of Others      477             Drama,Thriller
# Incendies                714          Drama,Mystery,War
# El secreto de sus ojos   743      Drama,Mystery,Romance
# Taare Zameen Par         992         Drama,Family,Music
#
#                                                               Description  \
# Title
# The Prestige            Two stage magicians engage in competitive one-...
# Into the Wild           After graduating from Emory University, top st...
# Pan's Labyrinth         In the falangist Spain of 1944, the bookish yo...
# There Will Be Blood     A story of family, religion, hatred, oil and m...
# ...

# %% [markdown]
# **11-Find all movies that were released between 2006 and 2010, have a rating above 8.0, but made below the 25th percentile in revenue.**

# %%
movie[(movie['Year']>=2006) & (movie["Year"]<=2010) & (movie['Rating']>8) & 
      (movie['Revenue (Millions)'] < movie['Revenue (Millions)'].quantile(0.25))]
# Out:
#                      Rank               Genre  \
# Title
# 3 Idiots              431        Comedy,Drama
# The Lives of Others   477      Drama,Thriller
# Incendies             714   Drama,Mystery,War
# Taare Zameen Par      992  Drama,Family,Music
#
#                                                            Description  \
# Title
# 3 Idiots             Two friends are searching for their long lost ...
# The Lives of Others  In 1984 East Berlin, an agent of the secret po...
# Incendies            Twins journey to the Middle East to discover t...
# Taare Zameen Par     An eight-year-old boy is thought to be a lazy ...
#
#                                              Director  \
# Title
# 3 Idiots                              Rajkumar Hirani
# The Lives of Others  Florian Henckel von Donnersmarck
# Incendies                            Denis Villeneuve
# Taare Zameen Par                           Aamir Khan
#
# ...

# %% [markdown]
# **12-Finally give the feedback for all movies with 'Good' if the movie 'rating' is >= 8 and 'Average' if the movie rating doesn't follow the condition given.**

# %%
def rat_feedback(rating):
    if rating >= 8:
        return 'Good Movie'
    else:
        return 'Average Movie'

# %%
movie['feedback'] = movie['Rating'].apply(rat_feedback)

# %%
movie.head(10)
